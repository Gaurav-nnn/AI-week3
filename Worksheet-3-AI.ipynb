# %%
import matplotlib.pyplot as plt
import pandas as pd

# 1. Sorting and Subsetting:
# [1]
df = pd.read_csv("/content/Titanic-Dataset (1).csv")
df.info()
fare = df[["Fare"]]
fare.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
#       Fare
# 0   7.2500
# 1  71.2833
# 2   7.9250
# 3  53.1000
# 4   8.0500

# %%
# [2]
class_age = df[["Pclass", "Age"]]
class_age.head()
# Out:
#    Pclass   Age
# 0       3  22.0
# 1       1  38.0
# 2       3  26.0
# 3       1  35.0
# 4       3  35.0

# %%
# [3]
survived_together = df[["Survived", "Sex"]]
survived_together.head()
# Out:
#    Survived     Sex
# 0         0    male
# 1         1  female
# 2         1  female
# 3         1  female
# 4         0    male

# %%
# [2].  Subsetting
# 1
fare_gt_100 = df[df["Fare"] > 100]
fare_gt_100.tail(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 742          743         1       1
# 763          764         1       1
# 779          780         1       1
# 802          803         1       1
# 856          857         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 742              Ryerson, Miss. Susan Parker "Suzette"  female  21.0      2
# 763          Carter, Mrs. William Ernest (Lucile Polk)  female  36.0      1
# 779  Robert, Mrs. Edward Scott (Elisabeth Walton Mc...  female  43.0      0
# 802                Carter, Master. William Thornton II    male  11.0      1
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.0      1
#
#      Parch    Ticket      Fare            Cabin Embarked  fare_per_year  \
# 742      2  PC 17608  262.3750  B57 B59 B63 B66        C      12.494048
# 763      2    113760  120.0000          B96 B98        S       3.333333
# 779      1     24160  211.3375               B3        S       4.914826
# 802      2    113760  120.0000          B96 B98        S      10.909091
# 856      1     36928  164.8667              NaN        S       3.663704
#
#      fare per Class age group
# 742        262.3750     adult
# 763        120.0000     adult
# 779        211.3375     adult
# 802        120.0000     child
# 856        164.8667     adult

# %%
# 2.
Fiirst_class = df[df["Pclass"] == 1]
Fiirst_class.head(5)
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 11           12         1       1
# 23           24         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 11      0    113783  26.5500  C103        S
# 23      0    113788  35.5000    A6        S

# %%
# 3
female_under_18 = df[(df["Sex"] == "female") & (df["Age"] < 18)]
female_under_18.head(5)
# Out:
#     PassengerId  Survived  Pclass                                  Name  \
# 9            10         1       2   Nasser, Mrs. Nicholas (Adele Achem)
# 10           11         1       3       Sandstrom, Miss. Marguerite Rut
# 14           15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# 22           23         1       3           McGowan, Miss. Anna "Annie"
# 24           25         0       3         Palsson, Miss. Torborg Danira
#
#        Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 9   female  14.0      1      0   237736  30.0708   NaN        C
# 10  female   4.0      1      1  PP 9549  16.7000    G6        S
# 14  female  14.0      0      0   350406   7.8542   NaN        S
# 22  female  15.0      0      0   330923   8.0292   NaN        Q
# 24  female   8.0      3      1   349909  21.0750   NaN        S

# %%
# Subsetting Rows by Categorical variables:
# 1
embarked_c_or_s = df[(df["Embarked"] == "C") | (df["Embarked"] == "S")]
embarked_c_or_s.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# 2
first_second_class = df[(df["Pclass"] == 1) | (df["Pclass"] == 2)]
first_second_class.head(10)
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 9            10         1       2
# 11           12         1       1
# 15           16         1       2
# 17           18         1       2
# 20           21         0       2
# 21           22         1       2
# 23           24         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 21                              Beesley, Mr. Lawrence    male  34.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 9       0    237736  30.0708   NaN        C
# 11      0    113783  26.5500  C103        S
# 15      0    248706  16.0000   NaN        S
# 17      0    244373  13.0000   NaN        S
# 20      0    239865  26.0000   NaN        S
# 21      0    248698  13.0000   D56        S
# 23      0    113788  35.5000    A6        S

# %%
# 3 Exploratory Data Analysis Practice Exercise - 1.
# 1
df["fare_per_year"] = df["Fare"] / df["Age"]
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  fare_per_year
# 0      0         A/5 21171   7.2500   NaN        S       0.329545
# 1      0          PC 17599  71.2833   C85        C       1.875876
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0.304808
# 3      0            113803  53.1000  C123        S       1.517143
# 4      0            373450   8.0500   NaN        S       0.230000

# %%
# 2 Subset rows where fare per year is higher than 5, assigning this to high fare age.
high_fare_age = df[df["fare_per_year"] > 5]
high_fare_age.head(5)
# Out:
#     PassengerId  Survived  Pclass                                      Name  \
# 7             8         0       3            Palsson, Master. Gosta Leonard
# 16           17         0       3                      Rice, Master. Eugene
# 27           28         0       1            Fortune, Mr. Charles Alexander
# 43           44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# 50           51         0       3                Panula, Master. Juha Niilo
#
#        Sex   Age  SibSp  Parch         Ticket      Fare        Cabin Embarked  \
# 7     male   2.0      3      1         349909   21.0750          NaN        S
# 16    male   2.0      4      1         382652   29.1250          NaN        Q
# 27    male  19.0      3      2          19950  263.0000  C23 C25 C27        S
# 43  female   3.0      1      2  SC/Paris 2123   41.5792          NaN        C
# 50    male   7.0      4      1        3101295   39.6875          NaN        S
#
#     fare_per_year
# 7       10.537500
# 16      14.562500
# 27      13.842105
# 43      13.859733
# 50       5.669643

# %%
# 3. Sort high fare age by descending fare per year,
# assigning this to high fare age srt.
high_fare_age_srt = high_fare_age.sort_values(by="fare_per_year", ascending=  False)
high_fare_age_srt.head(5)
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 305          306         1       1   Allison, Master. Hudson Trevor    male
# 297          298         0       1     Allison, Miss. Helen Loraine  female
# 386          387         0       3  Goodwin, Master. Sidney Leonard    male
# 164          165         0       3     Panula, Master. Eino Viljami    male
# 183          184         1       2        Becker, Master. Richard F    male
#
#       Age  SibSp  Parch   Ticket      Fare    Cabin Embarked  fare_per_year
# 305  0.92      1      2   113781  151.5500  C22 C26        S     164.728261
# 297  2.00      1      2   113781  151.5500  C22 C26        S      75.775000
# 386  1.00      5      2  CA 2144   46.9000      NaN        S      46.900000
# 164  1.00      4      1  3101295   39.6875      NaN        S      39.687500
# 183  1.00      2      1   230136   39.0000       F4        S      39.000000

# %%
# 4. Select only the Name and fare per year columns of high fare age srt and save the result as result.
result = high_fare_age_srt.loc[:,["Name", "fare_per_year"]]
result.head(5)
# Out:
#                                 Name  fare_per_year
# 305   Allison, Master. Hudson Trevor     164.728261
# 297     Allison, Miss. Helen Loraine      75.775000
# 386  Goodwin, Master. Sidney Leonard      46.900000
# 164     Panula, Master. Eino Viljami      39.687500
# 183        Becker, Master. Richard F      39.000000

# %%
# 3.2 Exploratory Data Analysis Practice Exercise - 1.

# 1. Add a column to the Titanic dataset, fare per class, containing the fare divided by the passenger class i.e. Fare / Pclass.
df["fare per Class"] = (df["Fare"]/df["Pclass"])
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  fare_per_year  \
# 0      0         A/5 21171   7.2500   NaN        S       0.329545
# 1      0          PC 17599  71.2833   C85        C       1.875876
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0.304808
# 3      0            113803  53.1000  C123        S       1.517143
# 4      0            373450   8.0500   NaN        S       0.230000
#
#    fare per Class
# 0        2.416667
# 1       71.283300
# 2        2.641667
# 3       53.100000
# 4        2.683333

# %%
# 2. Subset rows where the passenger is male (Sex is ”male”) and an adult (Age is greater than or equal to 18), assigning this to adult males.
adult_males = df[(df["Sex"] == "male") & (df["Age"] > 18)]
adult_males.head(5)
# Out:
#     PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 0             1         0       3         Braund, Mr. Owen Harris  male  22.0
# 4             5         0       3        Allen, Mr. William Henry  male  35.0
# 6             7         0       1         McCarthy, Mr. Timothy J  male  54.0
# 12           13         0       3  Saundercock, Mr. William Henry  male  20.0
# 13           14         0       3     Andersson, Mr. Anders Johan  male  39.0
#
#     SibSp  Parch     Ticket     Fare Cabin Embarked  fare_per_year  \
# 0       1      0  A/5 21171   7.2500   NaN        S       0.329545
# 4       0      0     373450   8.0500   NaN        S       0.230000
# 6       0      0      17463  51.8625   E46        S       0.960417
# 12      0      0  A/5. 2151   8.0500   NaN        S       0.402500
# 13      1      5     347082  31.2750   NaN        S       0.801923
#
#     fare per Class
# 0         2.416667
# 4         2.683333
# 6        51.862500
# 12        2.683333
# 13       10.425000

# %%
# 3. Sort adult males by descending fare per class, assigning this to adult males srt.
adult_males_srt = df.sort_values(by = "fare per Class", ascending = False)
adult_males_srt.head(5)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 737          738         1       1              Lesurer, Mr. Gustave J
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 438          439         0       1                   Fortune, Mr. Mark
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 88   female  23.0      3      2     19950  263.0000  C23 C25 C27        S
# 438    male  64.0      1      4     19950  263.0000  C23 C25 C27        S
#
#      fare_per_year  fare per Class
# 737      14.637977        512.3292
# 258      14.637977        512.3292
# 679      14.231367        512.3292
# 88       11.434783        263.0000
# 438       4.109375        263.0000

# %%
# 4. Select only the Name, Age, and fare per class columns of adult males srt and save the result as result.
result = adult_males_srt.loc[ : , ["Name", "Age", "fare per Class"]]
result.head(5)
# Out:
#                                    Name   Age  fare per Class
# 737              Lesurer, Mr. Gustave J  35.0        512.3292
# 258                    Ward, Miss. Anna  35.0        512.3292
# 679  Cardeza, Mr. Thomas Drake Martinez  36.0        512.3292
# 88           Fortune, Miss. Mabel Helen  23.0        263.0000
# 438                   Fortune, Mr. Mark  64.0        263.0000

# %%
# 3.3 Exploratory Data Analysis with Group-by Method Practice Exercise:

# 1. Calculate the total Fare paid across all passengers in the Titanic dataset.
total_fare = df["Fare"].sum()
total_fare
# Out:
# np.float64(28693.9493)

# %%
# 2. Subset for passengers in first class (Pclass is 1) and calculate their total fare.
first_class_fare = df[df["Pclass"] == 1]["Fare"].sum()
first_class_fare
# Out:
# np.float64(18177.4125)

# %%
# 3. Do the same for second class (Pclass is 2) and third class (Pclass is 3).
second_class_fare = df[df["Pclass"] == 2]["Fare"].sum()
second_class_fare
# Out:
# np.float64(3801.8417)

# %%
third_class_fare = df[df["Pclass"] == 3]["Fare"].sum()
third_class_fare
# Out:
# np.float64(6714.6951)

# %%
# 4. Combine the fare totals from first, second, and third classes into a list.
fare_by_class = [first_class_fare, second_class_fare, third_class_fare]
fare_by_class
# Out:
# [np.float64(18177.4125), np.float64(3801.8417), np.float64(6714.6951)]

# %%
# 5. Divide the totals for each class by the overall total fare to get the proportion of fare revenue by class.
prop_by_class = [fare / total_fare * 100 for fare in fare_by_class]
prop_by_class
# Out:
# [np.float64(63.349287718996564),
#  np.float64(13.24962855496507),
#  np.float64(23.401083726038365)]

# %%
# 1. Create a new column, age group, that categorizes passengers into
# "child" (age < 18), "adult" (age18{64), and "senior" (age 65 and above).
df["age group"] =  ["child" if age < 18 else "adult" if age <= 64 else "senior" for age in df["Age"]]
df.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked  \
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q
#
#      fare_per_year  fare per Class age group
# 886       0.481481        6.500000     adult
# 887       1.578947       30.000000     adult
# 888            NaN        7.816667    senior
# 889       1.153846       30.000000     adult
# 890       0.242188        2.583333     adult

# %%
# 2.Calculate the total number of passengers on the Titanic.
total_passengers = len(df)
total_passengers
# Out:
# 891

# %%
# 3. Count the number of passengers in each age group.
total_child = (df["age group"] == "child").sum()
total_child
total_adult = (df["age group"] == "adult").sum()
total_adult
total_senior = (df["age group"] == "senior").sum()
total_senior
# Out:
# np.int64(113)

# %%
# 4. Divide the count of each age group by the total number of passengers
# to get the proportion of passengers in each age group.
proportion_child = total_child / total_passengers * 100
print(str(proportion_child) + " %")
proportion_adult = total_adult / total_passengers * 100
print(str(proportion_adult) + " %")
proportion_senior = total_senior / total_passengers * 100
print(str(proportion_senior) + " %")
# Out:
# 12.682379349046016 %
# 66.21773288439955 %
# 21.099887766554435 %
